# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup as s
from urllib.request import urlopen as u
import matplotlib.pyplot as plt
import seaborn as sns

# %%
link="https://www.flipkart.com/search?q=asus+laptop&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&otracker1=AS_QueryStore_OrganicAutoSuggest_1_3_na_na_na&as-pos=1&as-type=RECENT&suggestionId=asus+laptop%7CLaptops&requestId=3df58f56-1e2a-47f1-a23d-ee265cd991f7&as-searchtext=asu"
pagecontent=u(link)
pagecode=pagecontent.read()

# %%
page_file=s(pagecode)
print(page_file.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="https://rukminim1.flixcart.com" rel="preconnect"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app_modules.chunk.94b5e7.css" rel="stylesheet"/>
#   <link href="//static-assets-web.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.dd97f3.css" rel="stylesheet"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="102988293558" property="fb:page_id"/>
#   <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
#   <meta content="noodp" name="robots"/>
#   <link href="https://static-assets-web.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
#   <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
#   <meta content="website" property="og:type"/>
# ...

# %%
modelname=page_file.find("div",{"class":'_4rR01T'})
print(modelname.text)
# Out:
# ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and L...

# %%
productname=[]
modelname=page_file.findAll("div",{"class":'_4rR01T'})
for i in modelname:
    p=i.text
    productname.append(p)

# %%
productname
# Out:
# ['ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 GB/512 GB SSD/Windows 11 Home) X515JA-EJ362WS Thin and L...',
#  'ASUS Core i3 10th Gen - (4 GB + 32 GB Optane/512 GB SSD/Windows 10 Home) X515JA-EJ372TS Thin and Light...',
#  'ASUS ROG Strix Ryzen 7 Octa Core 4800H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce...',
#  'ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 GB/256 GB SSD/Windows 10 Home) X515EA-EJ302TS Thin and L...',
#  'ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB323TS Thin and Li...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce G...',
#  'ASUS VivoBook 15 (2021) Core i5 11th Gen - (8 GB/1 TB HDD/256 GB SSD/Windows 10 Home) X515EA-EJ502TS T...',
#  'ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 GB/512 GB SSD/Windows 10 Home) X413EA-EB513TS Thin and Li...',
# ...

# %%
len(productname)
# Out:
# 24

# %%
rating=[]
ratingname=page_file.findAll("div",{"class":'_3LWZlK'})
for i in ratingname:
    p=i.text
    rating.append(p)

# %%
rating
# Out:
# ['4.4',
#  '4.3',
#  '4.6',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.5',
#  '4.5',
#  '3.9',
#  '4.3',
#  '4.3',
#  '4.4',
#  '4.5',
#  '4.4',
#  '4.5',
#  '4.5',
#  '5',
#  '4.5',
#  '4.4',
#  '4.3',
#  '4.6',
#  '4.4',
#  '5',
#  '5',
#  '4.4',
#  '5',
#  '1',
#  '4.3',
#  '5',
#  '5',
#  '4.5',
#  '5',
#  '4',
#  '4.6',
#  '5',
#  '5']

# %%
len(rating)
# Out:
# 37

# %%
del rating[:13]

# %%
len(rating)
# Out:
# 24

# %%
offers=[]
of=page_file.findAll("div",{"class":'_3Ay6Sb'})
for i in of:
    p=i.text
    offers.append(p)

# %%
offers
# Out:
# ['21% off',
#  '26% off',
#  '21% off',
#  '27% off',
#  '25% off',
#  '28% off',
#  '25% off',
#  '25% off',
#  '17% off',
#  '20% off',
#  '22% off',
#  '20% off',
#  '23% off',
#  '26% off',
#  '26% off',
#  '22% off',
#  '32% off',
#  '20% off',
#  '25% off',
#  '24% off',
#  '20% off',
#  '26% off',
#  '32% off',
#  '20% off',
#  '24% off',
#  '27% off',
#  '32% off',
#  '21% off']

# %%
len(offers)
# Out:
# 28

# %%
del offers[:4]

# %%
len(offers)
# Out:
# 24

# %%
price=[]
pr=page_file.findAll("div",{"class":'_30jeq3 _1_WHN1'})
for i in pr:
    p=i.text
    price.append(p)

# %%
price
# Out:
# ['₹39,990',
#  '₹36,990',
#  '₹81,990',
#  '₹36,490',
#  '₹45,990',
#  '₹60,990',
#  '₹50,990',
#  '₹54,990',
#  '₹54,990',
#  '₹33,990',
#  '₹34,990',
#  '₹48,990',
#  '₹54,990',
#  '₹68,990',
#  '₹66,490',
#  '₹36,990',
#  '₹45,990',
#  '₹74,990',
#  '₹37,590',
#  '₹54,990',
#  '₹63,990',
#  '₹49,990',
#  '₹36,990',
#  '₹83,990']

# %%
len(price)
# Out:
# 24

# %%
len(productname),len(rating),len(price),len(offers)
# Out:
# (24, 24, 24, 24)

# %%
d=({'productname':productname,'rating':rating,'price':price,'offers':offers})
df=pd.DataFrame(d)

# %%
df
# Out:
#                                           productname rating    price   offers
# 0   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...    4.5  ₹39,990  25% off
# 1   ASUS Core i3 10th Gen - (4 GB + 32 GB Optane/5...    4.4  ₹36,990  28% off
# 2   ASUS ROG Strix Ryzen 7 Octa Core 4800H - (8 GB...    4.5  ₹81,990  25% off
# 3   ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 ...    4.5  ₹36,490  25% off
# 4   ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...      5  ₹45,990  17% off
# 5   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    4.5  ₹60,990  20% off
# 6   ASUS VivoBook 15 (2021) Core i5 11th Gen - (8 ...    4.4  ₹50,990  22% off
# 7   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...    4.3  ₹54,990  20% off
# 8   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...    4.6  ₹54,990  23% off
# 9   ASUS Core i3 10th Gen - (4 GB/1 TB HDD/Windows...    4.4  ₹33,990  26% off
# 10  ASUS VivoBook 15 Ryzen 3 Dual Core - (4 GB/256...      5  ₹34,990  26% off
# ...

# %%
df.dtypes
# Out:
# productname    object
# rating         object
# price          object
# offers         object
# dtype: object

# %%
df.to_csv("shopping2.csv")

# %%
data=pd.read_csv("shopping2.csv")
data
# Out:
#     Unnamed: 0                                        productname  rating  \
# 0            0  ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...     4.5
# 1            1  ASUS Core i3 10th Gen - (4 GB + 32 GB Optane/5...     4.4
# 2            2  ASUS ROG Strix Ryzen 7 Octa Core 4800H - (8 GB...     4.5
# 3            3  ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 ...     4.5
# 4            4  ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...     5.0
# 5            5  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5
# 6            6  ASUS VivoBook 15 (2021) Core i5 11th Gen - (8 ...     4.4
# 7            7  ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.3
# 8            8  ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.6
# 9            9  ASUS Core i3 10th Gen - (4 GB/1 TB HDD/Windows...     4.4
# 10          10  ASUS VivoBook 15 Ryzen 3 Dual Core - (4 GB/256...     5.0
# 11          11  ASUS Core i5 10th Gen - (8 GB + 32 GB Optane/5...     5.0
# ...

# %%
df['rating']=df['rating'].astype(float)

# %%
df.dtypes
# Out:
# productname     object
# rating         float64
# price           object
# offers          object
# dtype: object

# %%
d=df['price']

# %%
temp=[]
import re
t=re.compile(r'[^\d]+')
for i in d:
    r=t.sub('',i)
    temp.append(r)
print(temp)
# Out:
# ['39990', '36990', '81990', '36490', '45990', '60990', '50990', '54990', '54990', '33990', '34990', '48990', '54990', '68990', '66490', '36990', '45990', '74990', '37590', '54990', '63990', '49990', '36990', '83990']

# %%
df['price']=temp
df
# Out:
#                                           productname  rating  price   offers
# 0   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...     4.5  39990  25% off
# 1   ASUS Core i3 10th Gen - (4 GB + 32 GB Optane/5...     4.4  36990  28% off
# 2   ASUS ROG Strix Ryzen 7 Octa Core 4800H - (8 GB...     4.5  81990  25% off
# 3   ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 ...     4.5  36490  25% off
# 4   ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...     5.0  45990  17% off
# 5   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5  60990  20% off
# 6   ASUS VivoBook 15 (2021) Core i5 11th Gen - (8 ...     4.4  50990  22% off
# 7   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.3  54990  20% off
# 8   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.6  54990  23% off
# 9   ASUS Core i3 10th Gen - (4 GB/1 TB HDD/Windows...     4.4  33990  26% off
# 10  ASUS VivoBook 15 Ryzen 3 Dual Core - (4 GB/256...     5.0  34990  26% off
# ...

# %%
df['price']=df['price'].astype(float)
df
# Out:
#                                           productname  rating    price  \
# 0   ASUS VivoBook 15 (2021) Core i3 10th Gen - (8 ...     4.5  39990.0
# 1   ASUS Core i3 10th Gen - (4 GB + 32 GB Optane/5...     4.4  36990.0
# 2   ASUS ROG Strix Ryzen 7 Octa Core 4800H - (8 GB...     4.5  81990.0
# 3   ASUS VivoBook 15 (2021) Core i3 11th Gen - (4 ...     4.5  36490.0
# 4   ASUS VivoBook Ultra 14 Core i3 11th Gen - (8 G...     5.0  45990.0
# 5   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...     4.5  60990.0
# 6   ASUS VivoBook 15 (2021) Core i5 11th Gen - (8 ...     4.4  50990.0
# 7   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.3  54990.0
# 8   ASUS VivoBook Ultra 14 Core i5 11th Gen - (8 G...     4.6  54990.0
# 9   ASUS Core i3 10th Gen - (4 GB/1 TB HDD/Windows...     4.4  33990.0
# 10  ASUS VivoBook 15 Ryzen 3 Dual Core - (4 GB/256...     5.0  34990.0
# 11  ASUS Core i5 10th Gen - (8 GB + 32 GB Optane/5...     5.0  48990.0
# ...

# %%
df.dtypes
# Out:
# productname     object
# rating         float64
# price          float64
# offers          object
# dtype: object

# %%
df.plot(kind='bar',x='productname',y='price',color='green')
# Out:
# <AxesSubplot:xlabel='productname'>

# %%
df.plot(kind='bar',x='productname',y='rating',color='red')
# Out:
# <AxesSubplot:xlabel='productname'>

# %%
df.hist('price','rating')
# Out:
# array([[<AxesSubplot:title={'center':'1.0'}>,
#         <AxesSubplot:title={'center':'4.0'}>,
#         <AxesSubplot:title={'center':'4.3'}>],
#        [<AxesSubplot:title={'center':'4.4'}>,
#         <AxesSubplot:title={'center':'4.5'}>,
#         <AxesSubplot:title={'center':'4.6'}>],
#        [<AxesSubplot:title={'center':'5.0'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
df.plot(kind='scatter',x='productname',y='rating',color='m')
# Out:
# <AxesSubplot:xlabel='productname', ylabel='rating'>

# %%
df.plot(kind='scatter',x='productname',y='price',color='m')
# Out:
# <AxesSubplot:xlabel='productname', ylabel='price'>
